# %% [markdown]
# # 00 scraping ATP calendar
#
# This currently relies on Selenium and EdgeChromium WebDriver. I also wasn't able to get this working in headless mode.
#
# If you do not have/do not wish to use Edge browser for this, you should be able to run the scraper by changing all EdgeChromium-specific lines in the source code (`infotennis/scrapers/scraping_functions_atp.py`) to your [preferred browser accordingly](https://pypi.org/project/webdriver-manager/).

# %%
# %pip install selenium
# %pip install webdriver-manager
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 6.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 522.6 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 3.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 162.4 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 459.9 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 400.4 kB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.4.2
#     Uninstalling websocket-client-1.4.2:
#       Successfully uninstalled websocket-client-1.4.2
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: attrs
# ...

# %%
import pandas as pd

from infotennis.scrapers.scraping_functions_atp import scrape_ATP_calendar

# %%
df_cal = scrape_ATP_calendar(2025)

# %%
df_cal
# Out:
#     year                                tournament tournament_id category  \
# 0   2025                                United Cup          9900    Other
# 1   2025  Brisbane International presented by Evie           339  ATP 250
# 2   2025       Bank of China Hong Kong Tennis Open           336  ATP 250
# 3   2025                    Adelaide International          8998  ATP 250
# 4   2025                               ASB Classic           301  ATP 250
# ..   ...                                       ...           ...      ...
# 61  2025                             Belgrade Open          4787  ATP 250
# 62  2025                              Moselle Open           341  ATP 250
# 63  2025                          Nitto ATP Finals           605    Other
# 64  2025                          Davis Cup Finals          8099    Other
# 65  2025      Next Gen ATP Finals presented by PIF          7696    Other
#
#                    location               date_start tournament_status  \
# ...
